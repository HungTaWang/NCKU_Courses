# %% [markdown]
# Q1 Answer :

# %%
# %%writefile Ex_Week2.cpp
#
# #include <iostream>
# using namespace std;
#
# int main()
# {
#
#     cout  << "\\n is used to start a new line";
#
#     return 0;
# }
# Out:
# Overwriting Ex_Week2.cpp

# %%
# %%shell
#
# g++ Ex_Week2.cpp -o Ex_Week2

# %%
# %%shell
#
# ./Ex_Week2
# Out:
# \n is used to start a new line

# %% [markdown]
# Q2 Answer : Nothing comes out.

# %%
# %%writefile Ex_Week2_2.cpp
#
# #include <iostream>
# using namespace std;
#
# int main()
# {
#
#     return 0;
#
#     cout  << "\\n is used to start a new line";
#
# }
# Out:
# Overwriting Ex_Week2_2.cpp

# %%
# %%shell
#
# g++ Ex_Week2_2.cpp -o Ex_Week2_2

# %%
# %%shell
#
# ./Ex_Week2_2

# %% [markdown]
# Q3 Answer :

# %%
# %%writefile Ex_Week2_3.cpp
#
# #include <iostream>
# using namespace std;
#
# int main()
# {
#
#     int number1;
#     int number2;
#
#     cin >> number1;
#     cin >> number2;
#
#     if(number1 > number2)
#  {
#     cout << "Input the first interger : " << number1 << endl;
#     cout << "Input the second interger : " << number2 << endl;
#     cout << "After " << number1 << " is devided by "<< number2 << " ,the remainder is : " << number1 % number2 << endl;
#  }
#
#
#     if(number1 < number2)
# {
#     cout << "Input the first interger : " << number2 << endl;
#     cout << "Input the second interger : " << number1 << endl;
#     cout << "After " << number2 << " is devided by "<< number1 << " ,the remainder is : " << number2 % number1 << endl;
# }
#
#     if(number1 == number2)
# {
#     cout << "Input the first interger : " << number1 << endl;
#     cout << "Input the second interger : " << number2 << endl;
#     cout << "After " << number1 << " is devided by "<< number2 << " ,the remainder is : " << "0" << endl;
# }
#
#     return 0;
# }
# Out:
# Overwriting Ex_Week2_3.cpp

# %%
# %%shell
#
# g++ Ex_Week2_3.cpp -o Ex_Week2_3

# %%
# %%shell
#
# ./Ex_Week2_3
# Out:
# 3
# 3
# Input the first interger : 3
# Input the second interger : 3
# After 3 is devided by 3 ,the remainder is : 0
