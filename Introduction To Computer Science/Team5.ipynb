# %%
# %%writefile final.cpp
#
# #include <iostream>
# #include <cstdlib>
# #include <ctime>
# #include <string>
# #include <vector>
# //#include <windows.h>
# //#include <conio.h>
#
# using namespace std;
#
#
# string sailor[9];
# int ay[9]={};
# string name[9] = {"伊志穎", "江家欣", "許語宸", "劉宸瑋", "林彥廷", "蔡侑傑", "陳靖則", "鄭兆博", "王泓達"};
#
# string m[9]={};
# int ax[9]={};
# string table[9] = { "boat traveler" , "crewman" , "Deputy captain" ,
#   "illegal immigration" ,  "boat cleaner", "boat mouse","boat cat","boat dog","captain's kid"};
#
# vector<vector<char> > hitBoard,myBoard;
# //char hitBoard[10][10]={};
# //char myBoard[10][10]={};
#
# int count = 1;
# int boardSize,size,life,kill=0;
# int enter_number; //改為全域變數
#
# string battleship_name;
#
# void suggestshotpoint(){
# srand(time(0));
# 	int bg,sgx,sgy;
#
# 	do{
# 		switch(count%4){
# 			case 0:
# 				bg=0;
# 				sgx=bg+rand()%(boardSize/2);
# 				sgy=bg+rand()%(boardSize/2);
# 				break;
# 			case 1:
# 				bg=(boardSize/2);
# 				sgx=bg+rand()%(boardSize/2);
# 				sgy=rand()%(boardSize/2);
# 				break;
# 			case 2:
# 				bg=(boardSize/2);
# 				sgx=rand()%(boardSize/2);
# 				sgy=bg+rand()%(boardSize/2);
# 				break;
# 			case 3:
# 				bg=(boardSize/2);
# 				sgx=bg+rand()%(boardSize/2);
# 				sgy=bg+rand()%(boardSize/2);
# 				break;
# 			default:
# 				break;
# 			}
# 		}while(hitBoard[sgy][sgx]=='X');
# 	cout<<"Suggest you shot: x="<<sgx<<" ,y="<<sgy<<endl;
#
#
# 	}
#
#
# //這個setpos程式已設定顏色開始，已設好自己的船的位子結束
# void setPos(){
# start:
#
#   cout << "What's the name of your battleship? : ";
#   cin >> battleship_name;
#   //戰船顏色選擇code開始
#   cout<<"Choose the color of your ship: "<<endl;
#   cout<<"1. Green"<<endl;
#   cout<<"2. Red"<<endl;
#   cout<<"3. Blue"<<endl;
#   cout<<"4. Yellow"<<endl;
#
#   cout << "My color choice is: ";
#   cin>>enter_number;
#
#   if(enter_number==1){
#     cout<<"\033[32mGreen ship engine start!\033[1m"<<endl;
#   }
#   else if(enter_number==2){
#     cout<<"\033[31mRed ship engine start!\033[1m"<<endl;
#   }
#   else if(enter_number==3){
#     cout<<"\033[34mBlue ship engine start!\033[1m"<<endl;
#   }
#   else if(enter_number==4){
#     cout<<"\033[33mYellow ship engine start!\033[1m"<<endl;
#   }
#   else {
#     cout<<"\033[30mWrong input: Using default color(Black).\033[1m"<<endl;
#   }
#   //戰船顏色選擇code結束
#
#   //放自己的船的位子
#   cout<<"\033[30mInput the size of your warship: \033[1m";
#   cin>>size;
#   int headX,headY,tailX,tailY;
#   cout<<"Input the head of the ship: \n";
#   cout<<"(headX, headY) = ";
#   cin>>headX>>headY;
#
#   cout<<"Input the tail of the ship: \n";
#   cout<<"(tailX, tailY) = ";
#   cin>>tailX>>tailY;
#
#   if(size>boardSize||(headX||headY||tailX||tailY)>=boardSize||(headX||headY||tailX||tailY)<0){
#     goto start;
#   }
#
#   if(headX<tailX)
#     swap(headX,tailX);
#   if(headY<tailY)
#     swap(headY,tailY);
#   if(headX!=tailX&&tailY!=headY){
#     cout<<"Invalid input! Try again!"<<endl;
#     goto start;
#   }
#   if(headX-tailX+headY-tailY+1!=size){
#     cout<<"Invalid input! Try again!"<<endl;
#     goto start;
#   }
#   //確認位置符合條件
#
#   if(headX==tailX){
#     for(int y=tailY;y<=headY;y++)
#       myBoard[y][headX]='O';
#   }
#   else if(headY==tailY){
#     for(int x=tailX;x<=headX;x++)
#       myBoard[headY][x]='O';
#   }
# }
#
#
# void card(){
#
#     cout<< battleship_name <<"的航海資訊卡: \n";
#     cout<<R"(                   ,:',:`,:')"<<endl;
#     cout<<R"(                __||_||_||_||__)"<<endl;
#     cout<<R"(           ____["""""""""""""""]____)"<<endl;
#     cout<<R"(           \ " '''''''''''''''''''' |)"<<endl;
#     cout<<R"(    ~~~^~^~^^~^~^~^~^~^~^~^~~^~^~^^~~^~^)"<<endl;
#
#
#     srand(time(0));
#     int R = rand() % 4;
#     int F = rand() % 8;
#     int V;
#     if(R == 3)
#     V = rand() % 6;
#     else
#     V = rand() % 7 + 6;
#
#     string weather[4] = {"大潮注意","暴潮警戒","巨浪警戒","晴朗無雨"};
#
#     cout << "\n今日航海天氣：" <<weather[R] << endl;
#     string winddirection[8] = {"東風","東南風","東北風","西風","西南風","西北風","南風","北風"};
#
#
#     cout << "\n今日風向：" <<winddirection[F] << endl;
#     string wind[14] = {"0級","1級","2級","3級","4級","5級","6級","7級","8級","9級","10級","11級","12級以上"};
#     string wave[14] = {"0～0.1","0.1～0.3","0.3～0.5","0.5～0.9","0.9～1.25","1.25～2.5","2.5～3","3～4","4～6","6～9","9～11","11～14",">14"};
#
#     cout << "\n風力：" << wind[V] << "\n\n浪高："<< wave[V] << " 公尺" << endl;
#
#     if(R<3 && V>6)
#     {
#         cout << "\n今日出航須提防風浪" << endl;
#     }
#     else
#     {
#         cout << "\n今日天氣適合出航" << endl;
#     }
#
# }
#
#
#
# void guess(){
#   char result;
#   int x,y;
#   bool valid=false,shot=false;
#   cout<<"\nGuess the position and shot enemy\n";
#   for(int i=0;i<boardSize;i++){
#     for(int j=0;j<boardSize;j++){
#       if(hitBoard[i][j]=='O')
#         shot=true;
#     }
#   }
#   if(!shot){
#     suggestshotpoint();//隨機建議攻擊位子
#   }
#
#   cout<<"(SX, SY) = ";
#   cin>>x>>y;
#
#   while(!valid){
#     cout<<"hit? (Y/N): ";
#     cin>>result;
#     switch(result){
#       case 'y':
#       case 'Y':
#         hitBoard[y][x]='O';
#         valid=true;
#         //cout<<"yes";
#         break;
#       case 'n':
#       case 'N':
#         hitBoard[y][x]='X';
#         valid=true;
#         //cout<<"no";
#         break;
#       default:
#         cout<<'\n'<<"Invalid input! Try again!"<<'\n';
#         break;
#     }
#   }
# }
#
# //顯示你的敵人攻擊你的點
#
# void enemyGuess(){
#   int x,y;
#   cout<<"Enemy guess: "<<endl;
#
#   cout<<"(SX, SY) = ";
#   cin>>x>>y;
#   if(myBoard[y][x]=='O'){
#     myBoard[y][x]='X';
#     cout<<"\nWe're hit by enemy!!!"<<endl;
#     life--;
# 		kill++;
# 		cout<<R"(__( )                 ( )__)"<<endl;
#     cout<<R"((_, |     __ __      | ,_))"<<endl;
#     cout<<R"(   \'\   /  ^   \    /'/)"<<endl;
#     cout<<R"(   '\'\,/\       \,/'/')"<<endl;
#     cout<<R"(     '\| []   [] |/')"<<endl;
#     cout<<R"(       (_  /^\  _))"<<endl;
#     cout<<R"(         \  ~  /)"<<endl;
#     cout<<R"(         /HHHHH\)"<<endl;
#     cout<<R"(       /'/{^^^}\'\)"<<endl;
#     cout<<R"(    _,/'/'  ^^  '\'\,_)"<<endl;
#     cout<<R"(  (_, |          | ,_))"<<endl;
#     cout<<R"(    (_)          (_))"<<endl;
#   }
# }
#
# void member(){
#
#
# cout<<size<<endl;
#
# srand( time(NULL) );
#
# for(int i=0;i<size;i++){
#
#   int y_element=rand()%((boardSize-1)+0);
# 	ay[i]={y_element};
# 	for(int j=0;j<i;j++){
# 	if(ay[i]==ay[j])
#   	{i=i-1;
# 		break;}
# 	}
#
#   int x_element=rand()%size+0;
# 	ax[i]={x_element};
# 	for(int j=0;j<i;j++){
# 	if(ax[i]==ax[j])
#   	{i=i-1;
# 		break;}
# 	}
#
# 	switch(ax[i]) {
#     case 0:
# 				m[i]=table[0];
# 				break;
#     case 1:
# 				m[i]=table[1];
#         break;
# 		case 2:
# 				m[i]=table[2];
# 				break;
# 		case 3:
# 				m[i]=table[3];
# 				break;
# 		case 4:
# 				m[i]=table[4];
# 				break;
# 		case 5:
# 				m[i]=table[5];
# 				break;
# 		case 6:
# 				m[i]=table[6];
# 				break;
# 		case 7:
# 				m[i]=table[7];
# 				break;
# 		case 8:
# 				m[i]=table[8];
# 				break;
#
# 	}
#
# 	switch(ay[i]) {
#     case 0:
#
# 				sailor[i]=name[0];
#
# 				break;
#     case 1:
#
# 				sailor[i]=name[1];
#
#         break;
# 		case 2:
#
# 				sailor[i]=name[2];
#
# 				break;
# 		case 3:
#
# 				sailor[i]=name[3];
#
# 				break;
# 		case 4:
#
# 				sailor[i]=name[4];
#
# 				break;
# 		case 5:
#
# 				sailor[i]=name[5];
#
# 				break;
# 		case 6:
#
# 				sailor[i]=name[6];
#
# 				break;
# 		case 7:
#
# 				sailor[i]=name[7];
#
# 				break;
# 		case 8:
#
# 				sailor[i]=name[8];
#
# 				break;
#
# 	}
# }
#
# }
#
# void print_member(){
# 	cout<<"--------------------------------------------------------------------"<<endl;
# 	cout<<"𓊝Our crew meambers:"<<endl;
# 	for(int i=0;i<life;i++){
# 		cout<<sailor[i]<<" : "<<m[i]<<endl;}
# 	for(int i=0;i<kill;i++){
# 		cout<<"dead💀"<<endl;}
#   cout << "\nLife Point: ";
# 	for(int j=0;j<life;j++){
# 			cout<< "💖 ";}
# 		cout<<endl;
#
# 	cout<<"--------------------------------------------------------------------"<<endl;
# }
#
#
# //主程式
# int main(){
# 	cout<<"Input the width(height) of the board: ";
#   cin>>boardSize;
#
#   for(int i=0;i<boardSize;i++){
#     myBoard.push_back(vector<char>());
#     hitBoard.push_back(vector<char>());
#     for(int j=0;j<boardSize;j++){
#       myBoard[i].push_back('~');
#       hitBoard[i].push_back('~');
#     }
#   }
#
#   setPos();
#   life=size;
#
# 	member();
#   cout<<"Start!!!\n";
#
#   while(life){
#     cout<<"\n ";
#     for(int i=0;i<boardSize;i++){
#       cout<<" "<<i;
#     }
#     cout<<"\n\n";
#     for(int i=0;i<boardSize;i++){
#       cout<<i<<" ";
#       for(int j=0;j<boardSize;j++){
#         if(myBoard[i][j]=='O'){
# 	        if (enter_number==1){
# 	      		cout<<"\033[32mO\033[1m"<<" ";
# 		     	}
# 	       	else if (enter_number==2){
# 	      		cout<<"\033[31mO\033[1m"<<" ";
# 	      	}
# 	       	else if (enter_number==3){
# 	      		cout<<"\033[34mO\033[1m"<<" ";
# 	       	}
# 	        else if (enter_number==4){
# 	       		cout<<"\033[33mO\033[1m"<<" ";
# 	      	}
#           else{
# 	      		cout<<"\033[30mO\033[1m"<<" ";
# 	      	}
#        	}
# 				else if(myBoard[i][j]=='X'){
# 					if (enter_number==1){
# 	        	cout<<"\033[32mX\033[1m"<<" ";
# 	      	}
# 	       	else if (enter_number==2){
# 	        	cout<<"\033[31mX\033[1m"<<" ";
# 	      	}
# 	      	else if (enter_number==3){
# 	      		cout<<"\033[34mX\033[1m"<<" ";
# 	      	}
# 	      	else if (enter_number==4){
# 	      		cout<<"\033[33mX\033[1m"<<" ";
# 	      	}
#           else{
# 	      		cout<<"\033[30mX\033[1m"<<" ";
# 	      	}
#         }
#
#       	else{
#        		cout<<"\033[30m~\033[1m"<<" ";
#        	}}
#
#     	cout<<endl;
#     }
#
#
#     cout<<endl<<endl<<" ";
#     for(int i=0;i<boardSize;i++){
#       cout<<" "<<i;
#     }
#     cout<<"\n\n";
#     for(int i=0;i<boardSize;i++){
#       cout<<i<<" ";
#       for(int j=0;j<boardSize;j++){
#         cout<<hitBoard[i][j]<<" ";
#       }
#       cout<<endl;
#     }
#
#
#
#     //回合計數器code開始
#     cout<<endl;
#     cout<<endl;
#     cout<<"目前是第";
#     cout<<count;
#     cout<<"回合"<<endl;
# 		cout<<endl;
#
#     card();
#     print_member();
# 		guess();
#     cout<<endl;
#     enemyGuess();
#
#   	count ++;
#
#     if(!life){
#
# 			print_member();
#       cout<<"目前是第";
#       count--;
#       cout<<count;
#       cout<<"回合，我們全軍陣亡QQ"<<endl;
#     }
#     //回合計數器code結束
#
# 	}
#
#   return 0;
# }
# Out:
# Overwriting final.cpp

# %%
# %%shell
# g++ final.cpp -o final
# ./final
# Out:
# Input the width(height) of the board: 8
# What's the name of your battleship? : Team5
# Choose the color of your ship:
# 1. Green
# 2. Red
# 3. Blue
# 4. Yellow
# My color choice is: 3
# Blue ship engine start!
# Input the size of your warship: 2
# Input the head of the ship:
# (headX, headY) = 1 1
# Input the tail of the ship:
# (tailX, tailY) = 1 2
# 2
# Start!!!
#
#   0 1 2 3 4 5 6 7
#
# 0 ~ ~ ~ ~ ~ ~ ~ ~
# 1 ~ O ~ ~ ~ ~ ~ ~
# 2 ~ O ~ ~ ~ ~ ~ ~
# 3 ~ ~ ~ ~ ~ ~ ~ ~
# 4 ~ ~ ~ ~ ~ ~ ~ ~
# 5 ~ ~ ~ ~ ~ ~ ~ ~
# 6 ~ ~ ~ ~ ~ ~ ~ ~
# 7 ~ ~ ~ ~ ~ ~ ~ ~
#
#
#   0 1 2 3 4 5 6 7
#
# 0 ~ ~ ~ ~ ~ ~ ~ ~
# 1 ~ ~ ~ ~ ~ ~ ~ ~
# 2 ~ ~ ~ ~ ~ ~ ~ ~
# 3 ~ ~ ~ ~ ~ ~ ~ ~
# 4 ~ ~ ~ ~ ~ ~ ~ ~
# 5 ~ ~ ~ ~ ~ ~ ~ ~
# 6 ~ ~ ~ ~ ~ ~ ~ ~
# 7 ~ ~ ~ ~ ~ ~ ~ ~
#
#
# 目前是第1回合
#
# Team5的航海資訊卡:
#                    ,:',:`,:'
#                 __||_||_||_||__
#            ____["""""""""""""""]____
#            \ " '''''''''''''''''''' |
#     ~~~^~^~^^~^~^~^~^~^~^~^~~^~^~^^~~^~^
#
# 今日航海天氣：暴潮警戒
#
# 今日風向：東南風
#
# 風力：11級
#
# ...
